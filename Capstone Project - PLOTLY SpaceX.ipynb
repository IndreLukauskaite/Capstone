# %%
# !pip install dash
# !pip install dash==1.19.0
# !pip install jupyter_dash
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: dash in c:\users\indre\anaconda3\lib\site-packages (2.7.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\indre\anaconda3\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\indre\anaconda3\lib\site-packages (from dash) (5.6.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\indre\anaconda3\lib\site-packages (from dash) (1.1.2)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\indre\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\indre\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: click>=5.1 in c:\users\indre\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (8.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\indre\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\indre\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.0.3)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\indre\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: colorama in c:\users\indre\anaconda3\lib\site-packages (from click>=5.1->Flask>=1.0.4->dash) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\indre\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: six in c:\users\indre\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\indre\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Collecting dash==1.19.0
#   Downloading dash-1.19.0.tar.gz (75 kB)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\indre\anaconda3\lib\site-packages (from dash==1.19.0) (1.1.2)
# Collecting flask-compress
#   Downloading Flask_Compress-1.13-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: plotly in c:\users\indre\anaconda3\lib\site-packages (from dash==1.19.0) (5.6.0)
# Collecting dash_renderer==1.9.0
#   Downloading dash_renderer-1.9.0.tar.gz (1.0 MB)
# Collecting dash-core-components==1.15.0
#   Downloading dash_core_components-1.15.0.tar.gz (3.5 MB)
# Collecting dash-html-components==1.1.2
#   Downloading dash_html_components-1.1.2.tar.gz (188 kB)
# Collecting dash-table==4.11.2
#   Downloading dash_table-4.11.2.tar.gz (1.8 MB)
# Requirement already satisfied: future in c:\users\indre\anaconda3\lib\site-packages (from dash==1.19.0) (0.18.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\indre\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\indre\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\indre\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.3)
# Requirement already satisfied: click>=5.1 in c:\users\indre\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (8.0.4)
# Requirement already satisfied: colorama in c:\users\indre\anaconda3\lib\site-packages (from click>=5.1->Flask>=1.0.4->dash==1.19.0) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\indre\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp39-cp39-win_amd64.whl (383 kB)
# Requirement already satisfied: six in c:\users\indre\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\indre\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (8.0.1)
# Building wheels for collected packages: dash, dash-core-components, dash-html-components, dash-renderer, dash-table
#   Building wheel for dash (setup.py): started
#   Building wheel for dash (setup.py): finished with status 'done'
#   Created wheel for dash: filename=dash-1.19.0-py3-none-any.whl size=84023 sha256=4375dea46d460695461343f7d190cc4758dbdce82d5b1e8f5d264a049a1a09d6
#   Stored in directory: c:\users\indre\appdata\local\pip\cache\wheels\d3\a4\51\d5de70e3fbed7165091a1972b5d60522f078d8f3b0938c6bc6
#   Building wheel for dash-core-components (setup.py): started
#   Building wheel for dash-core-components (setup.py): finished with status 'done'
#   Created wheel for dash-core-components: filename=dash_core_components-1.15.0-py3-none-any.whl size=3527003 sha256=a0f9fb1fa34433734ed9cef1a420d3f3d3aee2e1765827fbb3fb36016ddc161f
#   Stored in directory: c:\users\indre\appdata\local\pip\cache\wheels\17\6f\34\e5d7fe1c7189531b3c6c90266df517f73210b9ccf6aabd9c53
#   Building wheel for dash-html-components (setup.py): started
#   Building wheel for dash-html-components (setup.py): finished with status 'done'
#   Created wheel for dash-html-components: filename=dash_html_components-1.1.2-py3-none-any.whl size=427845 sha256=8590bd469151a354add9cc40290e8524f6012e7ec1aebc90d7548c88541f63cb
#   Stored in directory: c:\users\indre\appdata\local\pip\cache\wheels\89\69\97\d277cdcfc9018c0c50a181a3572895c323f324ce30616e988e
#   Building wheel for dash-renderer (setup.py): started
#   Building wheel for dash-renderer (setup.py): finished with status 'done'
#   Created wheel for dash-renderer: filename=dash_renderer-1.9.0-py3-none-any.whl size=1014861 sha256=615ea878c47146e0525681452a94e25d1f1d2946b7f232dfb34d444746339024
#   Stored in directory: c:\users\indre\appdata\local\pip\cache\wheels\9d\82\83\b39e9f2d6941ed7f500c579bb8c2e20c317638d84be58c63f2
#   Building wheel for dash-table (setup.py): started
#   Building wheel for dash-table (setup.py): finished with status 'done'
#   Created wheel for dash-table: filename=dash_table-4.11.2-py3-none-any.whl size=1839867 sha256=ed639ab1c43d9636e0993d31eed1d632de9fba658b0826fcdaa10e03267a5b99
#   Stored in directory: c:\users\indre\appdata\local\pip\cache\wheels\b6\7d\d0\1058eb26f3a2df4211086fb79bcb232357139aa1fc3abc15a2
# Successfully built dash dash-core-components dash-html-components dash-renderer dash-table
# Installing collected packages: brotli, flask-compress, dash-table, dash-renderer, dash-html-components, dash-core-components, dash
#   Attempting uninstall: dash-table
#     Found existing installation: dash-table 5.0.0
#     Uninstalling dash-table-5.0.0:
#       Successfully uninstalled dash-table-5.0.0
#   Attempting uninstall: dash-html-components
#     Found existing installation: dash-html-components 2.0.0
#     Uninstalling dash-html-components-2.0.0:
#       Successfully uninstalled dash-html-components-2.0.0
#   Attempting uninstall: dash-core-components
#     Found existing installation: dash-core-components 2.0.0
#     Uninstalling dash-core-components-2.0.0:
#       Successfully uninstalled dash-core-components-2.0.0
#   Attempting uninstall: dash
#     Found existing installation: dash 2.7.0
#     Uninstalling dash-2.7.0:
#       Successfully uninstalled dash-2.7.0
# Successfully installed brotli-1.0.9 dash-1.19.0 dash-core-components-1.15.0 dash-html-components-1.1.2 dash-renderer-1.9.0 dash-table-4.11.2 flask-compress-1.13
# Requirement already satisfied: jupyter_dash in c:\users\indre\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: ipykernel in c:\users\indre\anaconda3\lib\site-packages (from jupyter_dash) (6.9.1)
# Requirement already satisfied: flask in c:\users\indre\anaconda3\lib\site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: dash in c:\users\indre\anaconda3\lib\site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: nest-asyncio in c:\users\indre\anaconda3\lib\site-packages (from jupyter_dash) (1.5.5)
# Requirement already satisfied: retrying in c:\users\indre\anaconda3\lib\site-packages (from jupyter_dash) (1.3.3)
# Requirement already satisfied: requests in c:\users\indre\anaconda3\lib\site-packages (from jupyter_dash) (2.27.1)
# Requirement already satisfied: ansi2html in c:\users\indre\anaconda3\lib\site-packages (from jupyter_dash) (1.8.0)
# Requirement already satisfied: ipython in c:\users\indre\anaconda3\lib\site-packages (from jupyter_dash) (8.2.0)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\indre\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\indre\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: flask-compress in c:\users\indre\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.13)
# Requirement already satisfied: future in c:\users\indre\anaconda3\lib\site-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\indre\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: plotly in c:\users\indre\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.6.0)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\indre\anaconda3\lib\site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\indre\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\users\indre\anaconda3\lib\site-packages (from flask->jupyter_dash) (8.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\indre\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\indre\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.3)
# Requirement already satisfied: colorama in c:\users\indre\anaconda3\lib\site-packages (from click>=5.1->flask->jupyter_dash) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\indre\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: brotli in c:\users\indre\anaconda3\lib\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\indre\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\indre\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in c:\users\indre\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.1.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\indre\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (1.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\indre\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (0.1.2)
# Requirement already satisfied: decorator in c:\users\indre\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\indre\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.11.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\indre\anaconda3\lib\site-packages (from ipython->jupyter_dash) (61.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\indre\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\indre\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\indre\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.20)
# Requirement already satisfied: pickleshare in c:\users\indre\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: backcall in c:\users\indre\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\indre\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.3)
# Requirement already satisfied: pyzmq>=13 in c:\users\indre\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\indre\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\indre\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (4.9.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\indre\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter_dash) (302)
# Requirement already satisfied: wcwidth in c:\users\indre\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\indre\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel->jupyter_dash) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\indre\anaconda3\lib\site-packages (from plotly->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\indre\anaconda3\lib\site-packages (from requests->jupyter_dash) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\indre\anaconda3\lib\site-packages (from requests->jupyter_dash) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\indre\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\indre\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.9)
# Requirement already satisfied: executing in c:\users\indre\anaconda3\lib\site-packages (from stack-data->ipython->jupyter_dash) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\indre\anaconda3\lib\site-packages (from stack-data->ipython->jupyter_dash) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\indre\anaconda3\lib\site-packages (from stack-data->ipython->jupyter_dash) (2.0.5)
# Requirement already satisfied: plotly in c:\users\indre\anaconda3\lib\site-packages (5.6.0)
# Collecting plotly
#   Downloading plotly-5.11.0-py2.py3-none-any.whl (15.3 MB)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\indre\anaconda3\lib\site-packages (from plotly) (8.0.1)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.6.0
#     Uninstalling plotly-5.6.0:
#       Successfully uninstalled plotly-5.6.0
# Successfully installed plotly-5.11.0

# %%
from jupyter_dash.comms import _send_jupyter_config_comm_request
_send_jupyter_config_comm_request()

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objects as go

# %%
JupyterDash.infer_jupyter_proxy_config()

# %%
spacex_df = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv')

# %%
# Import required libraries
# import pandas as pd
# import dash
# import dash_html_components as html
# import dash_core_components as dcc
# from dash.dependencies import Input, Output
import plotly.express as px

# Read the airline data into pandas dataframe
# spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
# app = dash.Dash(__name__) # commented out as we are using JupyterDash instead of dash.Dash
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                # dcc.Dropdown(id='site-dropdown',...)
                                dcc.Dropdown(id='site-dropdown',
                                             options=[
                                                     {'label': 'All Sites', 'value': 'ALL'},
                                                     {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                                     {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                                     {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                                     {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}
                                                     ],
                                             value='ALL',
                                             placeholder='Select a Launch Site here',
                                             searchable=True
                                             # style={'width':'80%','padding':'3px','font-size':'20px','text-align-last':'center'}
                                             ),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                #dcc.RangeSlider(id='payload-slider',...)
                                dcc.RangeSlider(id='payload-slider',
                                                min=0,
                                                max=10000,
                                                step=1000,
                                                value=[min_payload, max_payload]
                                                ),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
        names='Launch Site', 
        title='Success Count for all launch sites')
        return fig
    else:
        # return the outcomes piechart for a selected site
        filtered_df=spacex_df[spacex_df['Launch Site']== entered_site]
        filtered_df=filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig=px.pie(filtered_df,values='class count',names='class',title=f"Total Success Launches for site {entered_site}")
        return fig

# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart',component_property='figure'),
                [Input(component_id='site-dropdown',component_property='value'),
                Input(component_id='payload-slider',component_property='value')])
def scatter(entered_site,payload):
    filtered_df = spacex_df[spacex_df['Payload Mass (kg)'].between(payload[0],payload[1])]
    # thought reusing filtered_df may cause issues, but tried it out of curiosity and it seems to be working fine
    
    if entered_site=='ALL':
        fig=px.scatter(filtered_df,x='Payload Mass (kg)',y='class',color='Booster Version Category',title='Success count on Payload mass for all sites')
        return fig
    else:
        fig=px.scatter(filtered_df[filtered_df['Launch Site']==entered_site],x='Payload Mass (kg)',y='class',color='Booster Version Category',title=f"Success count on Payload mass for site {entered_site}")
        return fig

# Run the app
if __name__ == '__main__':
    app.run_server(mode='inline', host='localhost')
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://localhost:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
